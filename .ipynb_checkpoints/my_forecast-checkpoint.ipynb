# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plthttp://localhost:8891/notebooks/my_forecast.ipynb#
import seaborn as sns

# %%
load_df = pd.read_csv("Data_load/Load_history.csv")

# %%
load_df.head()
# Out:
#    zone_id  year  month  day      h1      h2      h3      h4      h5      h6  \
# 0        1  2004      1    1  16,853  16,450  16,517  16,873  17,064  17,727
# 1        1  2004      1    2  14,155  14,038  14,019  14,489  14,920  16,072
# 2        1  2004      1    3  14,439  14,272  14,109  14,081  14,775  15,491
# 3        1  2004      1    4  11,273  10,415   9,943   9,859   9,881  10,248
# 4        1  2004      1    5  10,750  10,321  10,107  10,065  10,419  12,101
#
#     ...       h15     h16     h17     h18     h19     h20     h21     h22  \
# 0   ...    13,518  13,138  14,130  16,809  18,150  18,235  17,925  16,904
# 1   ...    16,127  15,448  15,839  17,727  18,895  18,650  18,443  17,580
# 2   ...    13,507  13,414  13,826  15,825  16,996  16,394  15,406  14,278
# 3   ...    14,207  13,614  14,162  16,237  17,430  17,218  16,633  15,238
# 4   ...    13,845  14,350  15,501  17,307  18,786  19,089  19,192  18,416
#
#       h23     h24
# 0  16,162  14,750
# 1  16,467  15,258
# ...

# %%
temp_df = pd.read_csv("Data_load/temperature_history.csv")

# %%
temp_df.head()
# Out:
#    station_id  year  month  day  h1  h2  h3  h4  h5  h6  ...    h15   h16  \
# 0           1  2004      1    1  46  46  45  41  39  35  ...   55.0  55.0
# 1           1  2004      1    2  43  44  46  46  47  47  ...   54.0  56.0
# 2           1  2004      1    3  45  46  46  44  43  46  ...   69.0  68.0
# 3           1  2004      1    4  63  62  62  62  60  60  ...   71.0  72.0
# 4           1  2004      1    5  64  63  65  64  64  64  ...   66.0  66.0
#
#     h17   h18   h19   h20   h21   h22   h23   h24
# 0  52.0  46.0  40.0  40.0  39.0  38.0  40.0  41.0
# 1  57.0  53.0  50.0  47.0  46.0  45.0  45.0  45.0
# 2  68.0  65.0  64.0  63.0  62.0  63.0  63.0  62.0
# 3  71.0  68.0  67.0  67.0  65.0  64.0  65.0  64.0
# 4  66.0  66.0  63.0  54.0  52.0  49.0  47.0  47.0
#
# [5 rows x 28 columns]

# %%
load_df_z1 = load_df[0:430] #4004/1/1/~2005/3/5/ zone1's load history
                            #It might correlate the temperatures of some 
                            #of the stations.
#load_df_z1.head

# %%
temp_df_s1 = temp_df[0:430]
#temp_df_s1.head

# %%
temp_df_s2 = temp_df[1643:(1643+430)]
#temp_df_s2.head

# %%
temp_df_s3 = temp_df[1643*2:(1643*2+430)]
temp_df_s4 = temp_df[1643*3:(1643*3+430)]
temp_df_s5 = temp_df[1643*4:(1643*4+430)]
temp_df_s6 = temp_df[1643*5:(1643*5+430)]
temp_df_s7 = temp_df[1643*6:(1643*6+430)]
temp_df_s8 = temp_df[1643*7:(1643*7+430)]
temp_df_s9 = temp_df[1643*8:(1643*8+430)]
temp_df_s10 = temp_df[1643*9:(1643*9+430)]
temp_df_s11 = temp_df[1643*10:(1643*10+430)]
#temp_df_s11.head

# %%
temp_stns_h1 = np.empty((430,11)) #hour 1 temperature for all 11 stations,
                                  #upto 2005/3/5, total of 430 observations.

# %%
for i in range(11):
    temp_stns_h1[:,i] = temp_df[1643*i:(1643*i+430)]['h1']
#temp_stns_h1[:,10]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#print(load_df_z1.ndim)
#print(temp_df_s1.ndim)
#load_df_z1['h1'].head

# %%
#load_df_z1['h1']

# %%
plt.scatter(temp_df_s1['h1'],load_df_z1['h1'])
plt.xlabel("Station 1 Temperature(F)")
plt.ylabel("Zone 1 Load(kW)")
plt.show()

# %%
print(temp_stns_h1[:,10].shape)
# Out:
# (430,)

# %%
 for i in range(11):
#   plt.subplot(11,1,i+1)
#   print(temp_stns_h1[:,i].size)
    plt.scatter(temp_stns_h1[:,i],load_df_z1['h1'])
    plt.xlabel("Station "+ str(i+1) + " Temperature(F)")
    plt.ylabel("Zone 1 Load(kW)")
    plt.show()
